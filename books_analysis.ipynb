# %%
import pandas as pd
# Out:
# /tmp/ipykernel_310962/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import matplotlib

# %%
books = pd.read_csv('books_dataset.csv')

# %%
books
# Out:
#                        Titulo                Autor  Ano  ISBN     Edição  \
# 0                    A Queda          Albert Camus  NaN   NaN     Pocket
# 1               O Estrangeiro         Albert Camus  NaN   NaN        NaN
# 2          A Queda da América       Allen Ginsberg  NaN   NaN     Pocket
# 3                      O Uivo       Allen Ginsberg  NaN   NaN     Pocket
# 4            Laranja Mecânica      Anthony Burgess  NaN   NaN   Brochura
# ..                        ...                  ...  ...   ...        ...
# 96        A Espada do Destino    Andrzej Sapkowski  NaN   NaN  Capa dura
# 97          Mitologia Nórdica          Neil Gaiman  NaN   NaN  Capa dura
# 98       O Mercador de Veneza  William Shakespeare  NaN   NaN     Pocket
# 99   O Retrato de Dorian Gray          Oscar Wilde  NaN   NaN  Capa dura
# 100     Crepúsculo dos Ídolos  Friedrich Nietzsche  NaN   NaN   Brochura
#
#     Classificação G.O.A.T Lido
# 0             Bom  DÙVIDA  Sim
# ...

# %%
# Top books sorted by author

books.head()
# Out:
#                Titulo            Autor  Ano  ISBN    Edição Classificação  \
# 0            A Queda      Albert Camus  NaN   NaN    Pocket           Bom
# 1       O Estrangeiro     Albert Camus  NaN   NaN       NaN           NaN
# 2  A Queda da América   Allen Ginsberg  NaN   NaN    Pocket         Médio
# 3              O Uivo   Allen Ginsberg  NaN   NaN    Pocket           Bom
# 4    Laranja Mecânica  Anthony Burgess  NaN   NaN  Brochura           Bom
#
#   G.O.A.T Lido
# 0  DÙVIDA  Sim
# 1     NaN  Não
# 2  DÙVIDA  Sim
# 3     SIM  Sim
# 4     SIM  Sim

# %%
# Last books sorted by author

books.tail()
# Out:
#                        Titulo                Autor  Ano  ISBN     Edição  \
# 96        A Espada do Destino    Andrzej Sapkowski  NaN   NaN  Capa dura
# 97          Mitologia Nórdica          Neil Gaiman  NaN   NaN  Capa dura
# 98       O Mercador de Veneza  William Shakespeare  NaN   NaN     Pocket
# 99   O Retrato de Dorian Gray          Oscar Wilde  NaN   NaN  Capa dura
# 100     Crepúsculo dos Ídolos  Friedrich Nietzsche  NaN   NaN   Brochura
#
#     Classificação G.O.A.T Lido
# 96          Médio     NÂO  Sim
# 97            Bom     NÂO  Sim
# 98            NaN     NaN  Não
# 99            NaN     NaN  Não
# 100           NaN     NaN  Não

# %%
books.sort_values(by=['Lido', 'G.O.A.T', 'Titulo'], ascending=False)
# Out:
#                                   Titulo                 Autor  Ano  ISBN  \
# 48                             Tristessa          Jack Kerouac  NaN   NaN
# 26                Sussurros na Escuridão       H. P. Lovecraft  NaN   NaN
# 28   Rum: Diário de um Jornalista Bêbado    Hunter S. Thompson  NaN   NaN
# 78                                 Queer  William S. Burroughs  NaN   NaN
# 66                        Piano Mecânico         Kurt Vonnegut  NaN   NaN
# ..                                   ...                   ...  ...   ...
# 75                     O Gato Por Dentro          William S. B  NaN   NaN
# 1                          O Estrangeiro          Albert Camus  NaN   NaN
# 57                            Doutor Sax          Jack Kerouac  NaN   NaN
# 100                Crepúsculo dos Ídolos   Friedrich Nietzsche  NaN   NaN
# 81          Cidade Grande Cidade Pequena          Jack Kerouac  NaN   NaN
#
#         Edição Classificação G.O.A.T Lido
# ...

# %%
autores = books['Autor'].value_counts()[:20]

# %%
autores.plot(kind='barh')
# Out:
# <Axes: ylabel='Autor'>

# %%
lidos = books['Lido'].value_counts()

# %%
lidos[:20].plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
