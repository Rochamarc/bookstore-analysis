# %%
import pandas as pd
# Out:
# /tmp/ipykernel_116809/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import json

# %%
file = None

with open('authors.json', 'r') as f:
    file = json.load(f)

# %%
file
# Out:
# [{'url': 'http://localhost:8000/authors/1.json',
#   'books': ['A QUEDA DA AMÉRICA', 'UIVO'],
#   'name': 'ALLEN GINSBERG',
#   'nationality': 'US'},
#  {'url': 'http://localhost:8000/authors/2.json',
#   'books': ['LARANJA MECÂNICA'],
#   'name': 'ANTHONY BURGUESS',
#   'nationality': 'UK'},
#  {'url': 'http://localhost:8000/authors/3.json',
#   'books': ['DRÁCULA'],
#   'name': 'BRAM STOKER',
#   'nationality': 'UK'},
#  {'url': 'http://localhost:8000/authors/4.json',
#   'books': ['UM CONTO DE NATAL'],
#   'name': 'CHARLES DICKENS',
#   'nationality': 'UK'},
#  {'url': 'http://localhost:8000/authors/5.json',
#   'books': ['O CLUBE DA LUTA', 'SOBREVIVENTE'],
#   'name': 'CHUCK PALAHNIUK',
#   'nationality': 'US'},
#  {'url': 'http://localhost:8000/authors/6.json',
#   'books': ['A GAROTA DE CASSIDY'],
#   'name': 'DAVID GOODIS',
#   'nationality': 'US'},
#  {'url': 'http://localhost:8000/authors/7.json',
#   'books': ['MEMÓRIAS DE UMA BEATNIK'],
#   'name': 'DIANE DI PRIMA',
# ...

# %%
df = pd.DataFrame(file).set_index('name')

# %%
df = df.drop(['url'], axis=1)

# %%
df
# Out:
#                                                                                books  \
# name
# ALLEN GINSBERG                                            [A QUEDA DA AMÉRICA, UIVO]
# ANTHONY BURGUESS                                                  [LARANJA MECÂNICA]
# BRAM STOKER                                                                [DRÁCULA]
# CHARLES DICKENS                                                  [UM CONTO DE NATAL]
# CHUCK PALAHNIUK                                      [O CLUBE DA LUTA, SOBREVIVENTE]
# DAVID GOODIS                                                   [A GAROTA DE CASSIDY]
# DIANE DI PRIMA                                             [MEMÓRIAS DE UMA BEATNIK]
# ERNEST HEMMINGWAY                         [O SOL TAMBEM SE LEVANTA, O VELHO E O MAR]
# F. SCOTT FITZGERALD                [O GRANDE GATSBY, O CURIOSO CASO DE BENJAMIN B...
# FIODOR DOSTOIEVSKI                 [DIÁRIOS DO SUBSOLO, CRIME E CASTIGO, NOITES B...
# ...
