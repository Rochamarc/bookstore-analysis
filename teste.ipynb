# %%
import pandas as pd
# Out:
# /tmp/ipykernel_42188/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import json

# %%
file = None 

with open('books_full.json','r') as f:
    file = json.load(f)

# %%
file
# Out:
# [{'url': 'http://localhost:8000/books/182.json',
#   'author_name': 'ALBERT CAMUS',
#   'author_nationality': 'ARGELIA',
#   'publisher_name': 'BESTBOLSO',
#   'format_name': 'POCKET',
#   'book_literatures': ['FRENCH LITERATURE'],
#   'book_genres': ['FICTION', 'PHILOSOPHY'],
#   'title': 'A QUEDA',
#   'published_at': '1956',
#   'isbn': '978-85-7799-008-5',
#   'was_read': 'YES',
#   'to_buy': 'No',
#   'author': 'http://localhost:8000/authors/50.json',
#   'format': 'http://localhost:8000/formats/1.json',
#   'publisher': 'http://localhost:8000/publishers/26.json'},
#  {'url': 'http://localhost:8000/books/183.json',
#   'author_name': 'ALBERT CAMUS',
#   'author_nationality': 'ARGELIA',
#   'publisher_name': 'BESTBOLSO',
#   'format_name': 'POCKET',
#   'book_literatures': ['FRENCH LITERATURE'],
#   'book_genres': [],
#   'title': 'O ESTRANGEIRO',
#   'published_at': '1942',
#   'isbn': '978-85-7799-270-6',
#   'was_read': 'NO',
#   'to_buy': 'No',
# ...

# %%
df = pd.DataFrame(file).set_index('author_name')

# %%
df = df.drop(['url','author','format','publisher'], axis=1)

# %%
df
# Out:
#                    author_nationality publisher_name     format_name  \
# author_name
# ALBERT CAMUS                  ARGELIA      BESTBOLSO          POCKET
# ALBERT CAMUS                  ARGELIA      BESTBOLSO          POCKET
# ALLEN GINSBERG                     US           L&PM          POCKET
# ALLEN GINSBERG                     US           L&PM          POCKET
# ANTHONY BURGUESS                   UK          ALEPH       PAPERBACK
# ...                               ...            ...             ...
# H. P. LOVECRAFT                    US       DARKSEID       HARDCOVER
# HERMAN MELVILLE                    US          ABRIL       HARDCOVER
# FIODOR DOSTOIEVSKI             RUSSIA  MARTIN CLARET       HARDCOVER
# CHUCK PALAHNIUK                    US           LEYA       PAPERBACK
# EDGAR ALLAN POE                    US        LAFONTE  MASS PAPERBACK
#
#                                book_literatures            book_genres  \
# author_name
# ...
